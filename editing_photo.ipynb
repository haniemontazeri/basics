# %%
import numpy as np 
from matplotlib import pyplot as plt
import pandas
from PIL import Image as img

# %%
image = img.open("img.jpg")
image.show()

# %%
arr_photo= np.array(image)

# %%
print(arr_photo.ndim)
print(arr_photo.shape)
# Out:
# 3
# (533, 400, 3)

# %%
print(arr_photo[200][200])
# Out:
# [32 32 44]

# %%
for i in range(0,500):
    arr_photo[i][50]= [0,0,0]

plt.imshow(arr_photo)

# %%
arr_photo[300][200]
# Out:
# array([28, 27, 35], dtype=uint8)

# %%
print("i liked worling with git")
# Out:
# i liked worling with git
